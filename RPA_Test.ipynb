# %%
import pyautogui
import time

pyautogui.PAUSE = 1.5

pyautogui.alert("O código será inicializado. Não mexa em nada enquanto o código estiver rodando.")

pyautogui.press('win')


pyautogui.write('RecForth')


pyautogui.press('enter')

while True:
    try:
        pyautogui.locateOnScreen('gravacao.png')
                
        pyautogui.press('f2')
        
        x, y, largura, altura = pyautogui.locateOnScreen('fechar_propaganda.png')

        pyautogui.click(x + largura/2, y + altura/2)
        
        
        break 
    except:
        time.sleep(1)



# apertar windows no teclado
pyautogui.press('win')


# digitar edge
pyautogui.write('edge')

# apertar enter
pyautogui.press('enter')

# entrar no Gmail
pyautogui.write('gmail')

pyautogui.press('enter')


# localizar a imagem e clicar no meio da imagem
x, y, largura, altura = pyautogui.locateOnScreen('busca_gmail.png')

pyautogui.click(x + largura/2, y + altura/2)

# esperar gmail
while True:
    try:
        pyautogui.locateOnScreen('logo_gmail.png')
        break # se executou o de cima, posso sair do loop
    except:
        time.sleep(1) 

# entrar em contatos
x, y, largura, altura = pyautogui.locateOnScreen('google_apps.png')

pyautogui.click(x + largura/2, y + altura/2)

x, y, largura, altura = pyautogui.locateOnScreen('contatos.png')

pyautogui.click(x + largura/2, y + altura/2)

# verificando se está na página de contatos
while True:
    try:
        pyautogui.locateOnScreen('logo_contatos.png')
        break 
    except:
        time.sleep(1) 

# exportando contatos
x, y, largura, altura = pyautogui.locateOnScreen('exportar.png')

pyautogui.click(x + largura/2, y + altura/2)


x, y, largura, altura = pyautogui.locateOnScreen('confirma_exportar.png')

pyautogui.click(x + largura/2, y + altura/2)


#pyautogui.alert("O código parou.")

# %%
import pandas as pd
import pyperclip


df = pd.read_csv(r"C:\Users\lucas\Downloads\contacts.csv")

df = df.dropna(axis=1)
display(df)
pyautogui.hotkey('ctrl', 'pgup')

for email in df['E-mail 1 - Value']:
    x, y, largura, altura = pyautogui.locateOnScreen('escrever.png')
    pyautogui.click(x + largura/2, y + altura/2)
    
    # escrever email
    pyautogui.write(email)
    
    # enter
    pyautogui.press('enter')
    
    # tab para o assunto do email
    pyautogui.press('tab')
    
    # escrever assunto
    pyautogui.write('Um assunto qualquer')
    
    # tab para escrever o e-mail
    pyautogui.press('tab')
    
    # escrever o e-mail
    texto = '''Lorem ipsum dolor sit amet, 
    consectetur adipiscing elit. In vitae tempor mi. 
    Curabitur eleifend rutrum est vitae aliquet. In erat ex, 
    bibendum nec egestas eget, fermentum sit amet nisl. 
    Sed hendrerit fermentum nunc non ultrices. 
    Sed neque neque, pellentesque quis purus quis, sagittis sollicitudin magna. 
    Proin gravida erat sem, quis ullamcorper lacus pretium et. 
    Integer sit amet sodales lorem. 
    Sed eu sem volutpat nulla egestas volutpat vel nec ligula. 
    Morbi efficitur eu est sit amet consequat. 
    Nunc eget suscipit est.'''
    

    pyperclip.copy(texto)
    
    pyautogui.hotkey('ctrl', 'v')
    

    # enviar
    pyautogui.hotkey('ctrl', 'enter')

while True:
    try:
        pyautogui.locateOnScreen('para_gravacao.png')
        pyautogui.press('f2')
        break 
    except:
        pyautogui.hotkey('alt', 'shift', 'tab')
    

pyautogui.alert('Isso é tudo pessoal!')
# Out:
#                                 Name       Given Name        Family Name  \
# 0  Lucas Meirelles Meirelles Silva 1  Lucas Meirelles  Meirelles Silva 1
#
#   Group Membership E-mail 1 - Type           E-mail 1 - Value  \
# 0     * myContacts              *   lucas.meirelles_@live.com
#
#      Phone 1 - Value Organization 1 - Name
# 0  +55 86 99972-7314               Não tem
# 'OK'
